# %%
# !pip install pymysql
# !pip install ipython-sql
# !pip install mysqlclient
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 1.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import pymysql

df = pd.read_excel("CovidDeaths.xlsx", index_col=0)
df
# Out:
#          continent     location       date  total_cases  new_cases  \
# iso_code
# AFG           Asia  Afghanistan 2020-02-24          1.0        1.0
# AFG           Asia  Afghanistan 2020-02-25          1.0        0.0
# AFG           Asia  Afghanistan 2020-02-26          1.0        0.0
# AFG           Asia  Afghanistan 2020-02-27          1.0        0.0
# AFG           Asia  Afghanistan 2020-02-28          1.0        0.0
# ...            ...          ...        ...          ...        ...
# ZWE         Africa     Zimbabwe 2021-04-26      38102.0       16.0
# ZWE         Africa     Zimbabwe 2021-04-27      38164.0       62.0
# ZWE         Africa     Zimbabwe 2021-04-28      38191.0       27.0
# ZWE         Africa     Zimbabwe 2021-04-29      38235.0       44.0
# ZWE         Africa     Zimbabwe 2021-04-30      38257.0       22.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# ...

# %%
db_name = "test"
db_host = "localhost"
db_username = "root"
db_password = "123"

conn = pymysql.connect(host=db_host,
                       port=int(1045),
                       user='root',
                       passwd=db_password,
                       db=db_name)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /opt/miniconda3/lib/python3.7/site-packages/pymysql/connections.py in connect(self, sock)
#     613                             sock = socket.create_connection(
# --> 614                                 (self.host, self.port), self.connect_timeout, **kwargs
#     615                             )
#
# /opt/miniconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     727         try:
# --> 728             raise err
#     729         finally:
#
# /opt/miniconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# ...

# %%
df.to_sql('CovidDeath', cnn)

# %%
# %load_ext sql

# %%
# %sql sqlite:///jupyter_sql_tutorial.db
# Out:
# __init__() got an unexpected keyword argument 'bind'
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %%sql
# SELECT *
# FROM CovidDeath
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])
